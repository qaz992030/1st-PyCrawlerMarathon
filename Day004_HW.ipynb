# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10966721210","type":"CreateEvent","actor":{"id":32475738,"login":"AnuroopSuresh","display_login":"AnuroopSuresh","gravatar_id":"","url":"https://api.github.com/users/AnuroopSuresh","avatar_url":"https://avatars.githubusercontent.com/u/32475738?"},"repo":{"id":224592245,"name":"AnuroopSuresh/v-new-poc","url":"https://api.github.com/repos/AnuroopSuresh/v-new-poc"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":"Prototype testing for vneo","pusher_type":"user"},"public":true,"created_at":"2019-11-28T07:52:42Z"},{"id":"10966721198","type":"PushEvent","actor":{"id":7252506,"login":"ehelle","display_login":"ehelle","gravatar_id":"","url":"https://api.github.com/users/ehelle","avatar_url":"https://avatars.githubusercontent.com/u/7252506?"},"repo":{"id":206080453,"name":"ehelle/SOSI-Vegnett","url":"https://api.github.com/repos/ehelle/SOSI-Vegnett"},"payload":{"push_id":4330808240,"size":3,"distinct_size":3,"ref":"refs/heads/master","head":"e68758f04124245fad756e0165148ce074dc7c5e","before":"167418da8a033cca3ef487eac4d31b4b7773dbaf","commits":[{"sha":"131c3d55927d6ecafd601fe07006a09469c88885","author":{"email":"ei.he@hotmail.com","name":"Einar Helle"},"message":"Oppsamling","distinct":true,"url":"https://api.github.com/repos/ehelle/SOSI-Vegnett/commits/131c3d55927d6ecafd601fe07006a09469c88885"},{"sha":"9d3c7cbe9c091271e586da836c68c9198325c800","author":{"email":"ei.he@hotmail.com","name":"Einar Helle"},"message":"Mapping trafikkreguleringer","distinct":true,"url":"https://api.github.com/repos/ehelle/SOSI-Vegnett/commits/9d3c7cbe9c091271e586da836c68c9198325c800"},{"sha":"e68758f04124245fad756e0165148ce074dc7c5e","author":{"email":"ei.he@hotmail.com","name":"Einar Helle"},"message":"merge adressenavn på veglenker","distinct":true,"url":"https://api.github.com/repos/ehelle/SOSI-Vegnett/commits/e68758f04124245fad756e0165148ce074dc7c5e"}]},"public":true,"created_at":"2019-11-28T07:52:42Z"},{"id":"10966721197","type":"IssuesEvent","actor":{"id":51185164,"login":"PKUDeleted","display_login":"PKUDeleted","gravatar_id":"","url":"https://api.github.com/users/PKUDeleted","avatar_url":"https://avatars.githubusercontent.com/u/51185164?"},"repo":{"id":189339809,"name":"PKUDeleted/Holes","url":"https://api.github.com/repos/PKUDeleted/Holes"},"payload":{"action":"closed","issue":{"url":"https://api.github.com/repos/PKUDeleted/Holes/issues/3237","repository_url":"https://api.github.com/repos/PKUDeleted/Holes","labels_url":"https://api.github.com/repos/PKUDeleted/Holes/issues/3237/labels{/name}","comments_url":"https://api.github.com/repos/PKUDeleted/Holes/issues/3237/comments","events_url":"https://api.github.com/repos/PKUDeleted/Holes/issues/3237/events","html_url":"https://github.com/PKUDeleted/Holes/issues/3237","id":520310326,"node_id":"MDU6SXNzdWU1MjAzMTAzMjY=","number":3237,"title":"#971288 求一个好用的翻墙软件 (关注:3 评论:1)","user":{"login":"PKUDeleted","id":51185164,"node_id":"MDQ6VXNlcjUxMTg1MTY0","avatar_url":"https://avatars3.githubusercontent.com/u/51185164?v=4","gravatar_id":"","url":"https://api.github.com/users/PKUDeleted","html_url":"https://github.com/PKUDeleted","followers_url":"https://api.github.com/users/PKUDeleted/followers","following_url":"https://api.github.com/users/PKUDeleted/following{/other_user}","gists_url":"https://api.github.com/users/PKUDeleted/gists{/gist_id}","starred_url":"https://api.github.com/users/PKUDeleted/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/PKUDeleted/subscriptions","organizations_url":"https://api.github.com/users/PKUDeleted/orgs","repos_url":"https://api.github.com/users/PKUDeleted/repos","events_url":"https://api.github.com/users/PKUDeleted/events{/privacy}","received_events_url":"https://api.github.com/users/PKUDeleted/received_events","type":"User","site_admin":false},"labels":[],"state":"closed","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2019-11-09T01:30:54Z","updated_at":"2019-11-28T0 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10966721210',
#   'type': 'CreateEvent',
#   'actor': {'id': 32475738,
#    'login': 'AnuroopSuresh',
#    'display_login': 'AnuroopSuresh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AnuroopSuresh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32475738?'},
#   'repo': {'id': 224592245,
#    'name': 'AnuroopSuresh/v-new-poc',
#    'url': 'https://api.github.com/repos/AnuroopSuresh/v-new-poc'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Prototype testing for vneo',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721198',
#   'type': 'PushEvent',
#   'actor': {'id': 7252506,
#    'login': 'ehelle',
#    'display_login': 'ehelle',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ehelle',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7252506?'},
#   'repo': {'id': 206080453,
#    'name': 'ehelle/SOSI-Vegnett',
#    'url': 'https://api.github.com/repos/ehelle/SOSI-Vegnett'},
#   'payload': {'push_id': 4330808240,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': 'e68758f04124245fad756e0165148ce074dc7c5e',
#    'before': '167418da8a033cca3ef487eac4d31b4b7773dbaf',
#    'commits': [{'sha': '131c3d55927d6ecafd601fe07006a09469c88885',
#      'author': {'email': 'ei.he@hotmail.com', 'name': 'Einar Helle'},
#      'message': 'Oppsamling',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ehelle/SOSI-Vegnett/commits/131c3d55927d6ecafd601fe07006a09469c88885'},
#     {'sha': '9d3c7cbe9c091271e586da836c68c9198325c800',
#      'author': {'email': 'ei.he@hotmail.com', 'name': 'Einar Helle'},
#      'message': 'Mapping trafikkreguleringer',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ehelle/SOSI-Vegnett/commits/9d3c7cbe9c091271e586da836c68c9198325c800'},
#     {'sha': 'e68758f04124245fad756e0165148ce074dc7c5e',
#      'author': {'email': 'ei.he@hotmail.com', 'name': 'Einar Helle'},
#      'message': 'merge adressenavn på veglenker',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ehelle/SOSI-Vegnett/commits/e68758f04124245fad756e0165148ce074dc7c5e'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721197',
#   'type': 'IssuesEvent',
#   'actor': {'id': 51185164,
#    'login': 'PKUDeleted',
#    'display_login': 'PKUDeleted',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PKUDeleted',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51185164?'},
#   'repo': {'id': 189339809,
#    'name': 'PKUDeleted/Holes',
#    'url': 'https://api.github.com/repos/PKUDeleted/Holes'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/PKUDeleted/Holes/issues/3237',
#     'repository_url': 'https://api.github.com/repos/PKUDeleted/Holes',
#     'labels_url': 'https://api.github.com/repos/PKUDeleted/Holes/issues/3237/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/PKUDeleted/Holes/issues/3237/comments',
#     'events_url': 'https://api.github.com/repos/PKUDeleted/Holes/issues/3237/events',
#     'html_url': 'https://github.com/PKUDeleted/Holes/issues/3237',
#     'id': 520310326,
#     'node_id': 'MDU6SXNzdWU1MjAzMTAzMjY=',
#     'number': 3237,
#     'title': '#971288 求一个好用的翻墙软件 (关注:3 评论:1)',
#     'user': {'login': 'PKUDeleted',
#      'id': 51185164,
#      'node_id': 'MDQ6VXNlcjUxMTg1MTY0',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/51185164?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/PKUDeleted',
#      'html_url': 'https://github.com/PKUDeleted',
#      'followers_url': 'https://api.github.com/users/PKUDeleted/followers',
#      'following_url': 'https://api.github.com/users/PKUDeleted/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/PKUDeleted/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/PKUDeleted/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/PKUDeleted/subscriptions',
#      'organizations_url': 'https://api.github.com/users/PKUDeleted/orgs',
#      'repos_url': 'https://api.github.com/users/PKUDeleted/repos',
#      'events_url': 'https://api.github.com/users/PKUDeleted/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/PKUDeleted/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-11-09T01:30:54Z',
#     'updated_at': '2019-11-28T07:52:42Z',
#     'closed_at': '2019-11-28T07:52:42Z',
#     'author_association': 'OWNER',
#     'body': '求一个好用的翻墙软件\n**2019-11-09 09:20:03 关注:3 评论:1**'}},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721195',
#   'type': 'PushEvent',
#   'actor': {'id': 49857903,
#    'login': 'Dal0328',
#    'display_login': 'Dal0328',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dal0328',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49857903?'},
#   'repo': {'id': 220658245,
#    'name': 'Dal0328/dal0328_study_hafs.github.io',
#    'url': 'https://api.github.com/repos/Dal0328/dal0328_study_hafs.github.io'},
#   'payload': {'push_id': 4330808239,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c8448e12f844860ab8833df385868387c10a102d',
#    'before': 'c2424d1b35981ef110caedf36006979aebbeb333',
#    'commits': [{'sha': 'c8448e12f844860ab8833df385868387c10a102d',
#      'author': {'email': 'dhkh1111@naver.com', 'name': 'Dal0328'},
#      'message': 'Update Readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Dal0328/dal0328_study_hafs.github.io/commits/c8448e12f844860ab8833df385868387c10a102d'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721199',
#   'type': 'PushEvent',
#   'actor': {'id': 7025952,
#    'login': 'jkpkonline',
#    'display_login': 'jkpkonline',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jkpkonline',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7025952?'},
#   'repo': {'id': 216409799,
#    'name': 'jkpkonline/pair-signal',
#    'url': 'https://api.github.com/repos/jkpkonline/pair-signal'},
#   'payload': {'push_id': 4330808244,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '234a72d8c001be4ded93a97e9d9ceac8deec899b',
#    'before': 'ef0307da4d22a686507a5f7a0d7047cd4963030c',
#    'commits': [{'sha': '234a72d8c001be4ded93a97e9d9ceac8deec899b',
#      'author': {'email': 'jkpkonline@users.noreply.github.com',
#       'name': 'jkpkonline'},
#      'message': 'jk commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jkpkonline/pair-signal/commits/234a72d8c001be4ded93a97e9d9ceac8deec899b'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721193',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 11637948,
#    'login': 'frnidito',
#    'display_login': 'frnidito',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/frnidito',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11637948?'},
#   'repo': {'id': 44026657,
#    'name': 'StephanTLavavej/mingw-distro',
#    'url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/issues/67',
#     'repository_url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro',
#     'labels_url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/issues/67/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/issues/67/comments',
#     'events_url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/issues/67/events',
#     'html_url': 'https://github.com/StephanTLavavej/mingw-distro/issues/67',
#     'id': 462352899,
#     'node_id': 'MDU6SXNzdWU0NjIzNTI4OTk=',
#     'number': 67,
#     'title': 'GCC 9.1 support soon?',
#     'user': {'login': 'oscarbg',
#      'id': 669305,
#      'node_id': 'MDQ6VXNlcjY2OTMwNQ==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/669305?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/oscarbg',
#      'html_url': 'https://github.com/oscarbg',
#      'followers_url': 'https://api.github.com/users/oscarbg/followers',
#      'following_url': 'https://api.github.com/users/oscarbg/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/oscarbg/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/oscarbg/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/oscarbg/subscriptions',
#      'organizations_url': 'https://api.github.com/users/oscarbg/orgs',
#      'repos_url': 'https://api.github.com/users/oscarbg/repos',
#      'events_url': 'https://api.github.com/users/oscarbg/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/oscarbg/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 509507060,
#       'node_id': 'MDU6TGFiZWw1MDk1MDcwNjA=',
#       'url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/labels/fixed',
#       'name': 'fixed',
#       'color': '006b75',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/milestones/13',
#      'html_url': 'https://github.com/StephanTLavavej/mingw-distro/milestone/13',
#      'labels_url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/milestones/13/labels',
#      'id': 4886023,
#      'node_id': 'MDk6TWlsZXN0b25lNDg4NjAyMw==',
#      'number': 13,
#      'title': 'v17.0',
#      'description': '',
#      'creator': {'login': 'StephanTLavavej',
#       'id': 4231088,
#       'node_id': 'MDQ6VXNlcjQyMzEwODg=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/4231088?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/StephanTLavavej',
#       'html_url': 'https://github.com/StephanTLavavej',
#       'followers_url': 'https://api.github.com/users/StephanTLavavej/followers',
#       'following_url': 'https://api.github.com/users/StephanTLavavej/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/StephanTLavavej/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/StephanTLavavej/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/StephanTLavavej/subscriptions',
#       'organizations_url': 'https://api.github.com/users/StephanTLavavej/orgs',
#       'repos_url': 'https://api.github.com/users/StephanTLavavej/repos',
#       'events_url': 'https://api.github.com/users/StephanTLavavej/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/StephanTLavavej/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 0,
#      'closed_issues': 3,
#      'state': 'closed',
#      'created_at': '2019-11-27T21:53:31Z',
#      'updated_at': '2019-11-27T21:54:39Z',
#      'due_on': None,
#      'closed_at': '2019-11-27T21:54:39Z'},
#     'comments': 10,
#     'created_at': '2019-06-30T00:10:50Z',
#     'updated_at': '2019-11-28T07:52:42Z',
#     'closed_at': '2019-11-27T21:50:40Z',
#     'author_association': 'NONE',
#     'body': 'asking similar to one year ago :-)\r\nhttps://github.com/StephanTLavavej/mingw-distro/issues/59'},
#    'comment': {'url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/issues/comments/559380987',
#     'html_url': 'https://github.com/StephanTLavavej/mingw-distro/issues/67#issuecomment-559380987',
#     'issue_url': 'https://api.github.com/repos/StephanTLavavej/mingw-distro/issues/67',
#     'id': 559380987,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM4MDk4Nw==',
#     'user': {'login': 'frnidito',
#      'id': 11637948,
#      'node_id': 'MDQ6VXNlcjExNjM3OTQ4',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/11637948?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/frnidito',
#      'html_url': 'https://github.com/frnidito',
#      'followers_url': 'https://api.github.com/users/frnidito/followers',
#      'following_url': 'https://api.github.com/users/frnidito/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/frnidito/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/frnidito/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/frnidito/subscriptions',
#      'organizations_url': 'https://api.github.com/users/frnidito/orgs',
#      'repos_url': 'https://api.github.com/users/frnidito/repos',
#      'events_url': 'https://api.github.com/users/frnidito/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/frnidito/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T07:52:42Z',
#     'updated_at': '2019-11-28T07:52:42Z',
#     'author_association': 'NONE',
#     'body': 'This is brilliant, thanks! '}},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721185',
#   'type': 'PushEvent',
#   'actor': {'id': 24299109,
#    'login': 'RiteshSaxena',
#    'display_login': 'RiteshSaxena',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RiteshSaxena',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24299109?'},
#   'repo': {'id': 210443566,
#    'name': 'ReloadedOS/android_vendor_qcom_opensource_interfaces',
#    'url': 'https://api.github.com/repos/ReloadedOS/android_vendor_qcom_opensource_interfaces'},
#   'payload': {'push_id': 4330808234,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/q',
#    'head': '0eb6079d9f689c49c53834c8b5eee7f0c1788bf4',
#    'before': '53b46ded30395540370137b4a99504ecab072e3a',
#    'commits': [{'sha': '0eb6079d9f689c49c53834c8b5eee7f0c1788bf4',
#      'author': {'email': 'riteshsax007@gmail.com', 'name': 'Ritesh Saxena'},
#      'message': 'Merge tag \'LA.UM.8.1.r1-11600-sm8150.0\' of https://source.codeaurora.org/quic/la/platform/vendor/qcom-opensource/interfaces into HEAD\n\n"LA.UM.8.1.r1-11600-sm8150.0"',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ReloadedOS/android_vendor_qcom_opensource_interfaces/commits/0eb6079d9f689c49c53834c8b5eee7f0c1788bf4'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z',
#   'org': {'id': 45596331,
#    'login': 'ReloadedOS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ReloadedOS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45596331?'}},
#  {'id': '10966721189',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 1483000,
#    'login': 'perexg',
#    'display_login': 'perexg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/perexg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1483000?'},
#   'repo': {'id': 199902161,
#    'name': 'alsa-project/alsa-ucm-conf',
#    'url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/comments/351630965',
#     'pull_request_review_id': 324103663,
#     'id': 351630965,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1MTYzMDk2NQ==',
#     'diff_hunk': '@@ -84,6 +72,7 @@ SectionDevice."Speaker" {\n \t\tPlaybackSwitch "Speaker Playback Switch"\n \t\tPlaybackChannels "2"\n \t\tPlaybackPriority "100"\n+\t\tJackHWMute "Headphone"',
#     'path': 'ucm2/sof-hda-dsp/HiFi.conf',
#     'position': 79,
#     'original_position': 23,
#     'commit_id': '3d03e4a76adb7376a67f2d52e0af08bc6d251618',
#     'original_commit_id': '3d03e4a76adb7376a67f2d52e0af08bc6d251618',
#     'user': {'login': 'perexg',
#      'id': 1483000,
#      'node_id': 'MDQ6VXNlcjE0ODMwMDA=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1483000?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/perexg',
#      'html_url': 'https://github.com/perexg',
#      'followers_url': 'https://api.github.com/users/perexg/followers',
#      'following_url': 'https://api.github.com/users/perexg/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/perexg/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/perexg/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/perexg/subscriptions',
#      'organizations_url': 'https://api.github.com/users/perexg/orgs',
#      'repos_url': 'https://api.github.com/users/perexg/repos',
#      'events_url': 'https://api.github.com/users/perexg/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/perexg/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This is PA or the UCM specification issue? The specification says this: _If **JackHWMute** is set, it indicates that when the jack is plugged in, the hardware automatically mutes some other device(s)._\r\n\r\nAnd JackHWMute belongs to the JackControl which is not defined in Speaker device.',
#     'created_at': '2019-11-28T07:52:41Z',
#     'updated_at': '2019-11-28T07:52:42Z',
#     'html_url': 'https://github.com/alsa-project/alsa-ucm-conf/pull/7#discussion_r351630965',
#     'pull_request_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7',
#     'author_association': 'MEMBER',
#     '_links': {'self': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/comments/351630965'},
#      'html': {'href': 'https://github.com/alsa-project/alsa-ucm-conf/pull/7#discussion_r351630965'},
#      'pull_request': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7',
#     'id': 345810262,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ1ODEwMjYy',
#     'html_url': 'https://github.com/alsa-project/alsa-ucm-conf/pull/7',
#     'diff_url': 'https://github.com/alsa-project/alsa-ucm-conf/pull/7.diff',
#     'patch_url': 'https://github.com/alsa-project/alsa-ucm-conf/pull/7.patch',
#     'issue_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/issues/7',
#     'number': 7,
#     'state': 'open',
#     'locked': False,
#     'title': 'Sof upstream',
#     'user': {'login': 'juimonen',
#      'id': 1136650,
#      'node_id': 'MDQ6VXNlcjExMzY2NTA=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1136650?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/juimonen',
#      'html_url': 'https://github.com/juimonen',
#      'followers_url': 'https://api.github.com/users/juimonen/followers',
#      'following_url': 'https://api.github.com/users/juimonen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/juimonen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/juimonen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/juimonen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/juimonen/orgs',
#      'repos_url': 'https://api.github.com/users/juimonen/repos',
#      'events_url': 'https://api.github.com/users/juimonen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/juimonen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-11-26T15:59:36Z',
#     'updated_at': '2019-11-28T07:52:42Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'f1e0060f58bbab33bee6297f3117003701deaebc',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7/commits',
#     'review_comments_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7/comments',
#     'review_comment_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/issues/7/comments',
#     'statuses_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/statuses/3d03e4a76adb7376a67f2d52e0af08bc6d251618',
#     'head': {'label': 'juimonen:sof_upstream',
#      'ref': 'sof_upstream',
#      'sha': '3d03e4a76adb7376a67f2d52e0af08bc6d251618',
#      'user': {'login': 'juimonen',
#       'id': 1136650,
#       'node_id': 'MDQ6VXNlcjExMzY2NTA=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/1136650?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/juimonen',
#       'html_url': 'https://github.com/juimonen',
#       'followers_url': 'https://api.github.com/users/juimonen/followers',
#       'following_url': 'https://api.github.com/users/juimonen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/juimonen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/juimonen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/juimonen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/juimonen/orgs',
#       'repos_url': 'https://api.github.com/users/juimonen/repos',
#       'events_url': 'https://api.github.com/users/juimonen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/juimonen/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 211301237,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTEzMDEyMzc=',
#       'name': 'alsa-ucm-conf-1',
#       'full_name': 'juimonen/alsa-ucm-conf-1',
#       'private': False,
#       'owner': {'login': 'juimonen',
#        'id': 1136650,
#        'node_id': 'MDQ6VXNlcjExMzY2NTA=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/1136650?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/juimonen',
#        'html_url': 'https://github.com/juimonen',
#        'followers_url': 'https://api.github.com/users/juimonen/followers',
#        'following_url': 'https://api.github.com/users/juimonen/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/juimonen/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/juimonen/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/juimonen/subscriptions',
#        'organizations_url': 'https://api.github.com/users/juimonen/orgs',
#        'repos_url': 'https://api.github.com/users/juimonen/repos',
#        'events_url': 'https://api.github.com/users/juimonen/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/juimonen/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/juimonen/alsa-ucm-conf-1',
#       'description': 'ALSA Use Case Manager configuration (and topologies)',
#       'fork': True,
#       'url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1',
#       'forks_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/forks',
#       'keys_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/teams',
#       'hooks_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/hooks',
#       'issue_events_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/events',
#       'assignees_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/tags',
#       'blobs_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/languages',
#       'stargazers_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/stargazers',
#       'contributors_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/contributors',
#       'subscribers_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/subscribers',
#       'subscription_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/subscription',
#       'commits_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/merges',
#       'archive_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/downloads',
#       'issues_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/juimonen/alsa-ucm-conf-1/deployments',
#       'created_at': '2019-09-27T11:09:06Z',
#       'updated_at': '2019-09-27T11:09:08Z',
#       'pushed_at': '2019-11-27T13:36:48Z',
#       'git_url': 'git://github.com/juimonen/alsa-ucm-conf-1.git',
#       'ssh_url': 'git@github.com:juimonen/alsa-ucm-conf-1.git',
#       'clone_url': 'https://github.com/juimonen/alsa-ucm-conf-1.git',
#       'svn_url': 'https://github.com/juimonen/alsa-ucm-conf-1',
#       'homepage': None,
#       'size': 185,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'forks': 1,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'alsa-project:master',
#      'ref': 'master',
#      'sha': '2e1f989533fec6077a07dc75f697d3f5e7060bed',
#      'user': {'login': 'alsa-project',
#       'id': 33286356,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzMjg2MzU2',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/33286356?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/alsa-project',
#       'html_url': 'https://github.com/alsa-project',
#       'followers_url': 'https://api.github.com/users/alsa-project/followers',
#       'following_url': 'https://api.github.com/users/alsa-project/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/alsa-project/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/alsa-project/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/alsa-project/subscriptions',
#       'organizations_url': 'https://api.github.com/users/alsa-project/orgs',
#       'repos_url': 'https://api.github.com/users/alsa-project/repos',
#       'events_url': 'https://api.github.com/users/alsa-project/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/alsa-project/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 199902161,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTk5MDIxNjE=',
#       'name': 'alsa-ucm-conf',
#       'full_name': 'alsa-project/alsa-ucm-conf',
#       'private': False,
#       'owner': {'login': 'alsa-project',
#        'id': 33286356,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjMzMjg2MzU2',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/33286356?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/alsa-project',
#        'html_url': 'https://github.com/alsa-project',
#        'followers_url': 'https://api.github.com/users/alsa-project/followers',
#        'following_url': 'https://api.github.com/users/alsa-project/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/alsa-project/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/alsa-project/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/alsa-project/subscriptions',
#        'organizations_url': 'https://api.github.com/users/alsa-project/orgs',
#        'repos_url': 'https://api.github.com/users/alsa-project/repos',
#        'events_url': 'https://api.github.com/users/alsa-project/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/alsa-project/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/alsa-project/alsa-ucm-conf',
#       'description': 'ALSA Use Case Manager configuration (and topologies)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf',
#       'forks_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/forks',
#       'keys_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/teams',
#       'hooks_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/hooks',
#       'issue_events_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/events',
#       'assignees_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/tags',
#       'blobs_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/languages',
#       'stargazers_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/stargazers',
#       'contributors_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/contributors',
#       'subscribers_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/subscribers',
#       'subscription_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/subscription',
#       'commits_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/merges',
#       'archive_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/downloads',
#       'issues_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/deployments',
#       'created_at': '2019-07-31T17:38:51Z',
#       'updated_at': '2019-11-23T14:45:41Z',
#       'pushed_at': '2019-11-27T13:36:50Z',
#       'git_url': 'git://github.com/alsa-project/alsa-ucm-conf.git',
#       'ssh_url': 'git@github.com:alsa-project/alsa-ucm-conf.git',
#       'clone_url': 'https://github.com/alsa-project/alsa-ucm-conf.git',
#       'svn_url': 'https://github.com/alsa-project/alsa-ucm-conf',
#       'homepage': None,
#       'size': 158,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 6,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'forks': 6,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7'},
#      'html': {'href': 'https://github.com/alsa-project/alsa-ucm-conf/pull/7'},
#      'issue': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/issues/7'},
#      'comments': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/issues/7/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/pulls/7/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/alsa-project/alsa-ucm-conf/statuses/3d03e4a76adb7376a67f2d52e0af08bc6d251618'}},
#     'author_association': 'CONTRIBUTOR'}},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z',
#   'org': {'id': 33286356,
#    'login': 'alsa-project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alsa-project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33286356?'}},
#  {'id': '10966721182',
#   'type': 'PushEvent',
#   'actor': {'id': 51324272,
#    'login': 'vehicleplus',
#    'display_login': 'vehicleplus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vehicleplus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51324272?'},
#   'repo': {'id': 189997880,
#    'name': 'vehicleplus/vehicleplus.github.io',
#    'url': 'https://api.github.com/repos/vehicleplus/vehicleplus.github.io'},
#   'payload': {'push_id': 4330808232,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b7cd7e790ed9ea74fe3531a8fe09291af384d24c',
#    'before': '763d0a56309998cde9ca2d2db14f52a1e4b6d363',
#    'commits': [{'sha': 'b7cd7e790ed9ea74fe3531a8fe09291af384d24c',
#      'author': {'email': '51324272+vehicleplus@users.noreply.github.com',
#       'name': 'vehicleplus'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vehicleplus/vehicleplus.github.io/commits/b7cd7e790ed9ea74fe3531a8fe09291af384d24c'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721173',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 47862718,
#    'login': 'adrianrevilla009',
#    'display_login': 'adrianrevilla009',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adrianrevilla009',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47862718?'},
#   'repo': {'id': 175437675,
#    'name': 'avanzosc/education',
#    'url': 'https://api.github.com/repos/avanzosc/education'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/avanzosc/education/comments/36173429',
#     'html_url': 'https://github.com/avanzosc/education/commit/8c1dd132b2cf6b41202792cc095ee6d94bf8c029#commitcomment-36173429',
#     'id': 36173429,
#     'node_id': 'MDEzOkNvbW1pdENvbW1lbnQzNjE3MzQyOQ==',
#     'user': {'login': 'adrianrevilla009',
#      'id': 47862718,
#      'node_id': 'MDQ6VXNlcjQ3ODYyNzE4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/47862718?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/adrianrevilla009',
#      'html_url': 'https://github.com/adrianrevilla009',
#      'followers_url': 'https://api.github.com/users/adrianrevilla009/followers',
#      'following_url': 'https://api.github.com/users/adrianrevilla009/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/adrianrevilla009/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/adrianrevilla009/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/adrianrevilla009/subscriptions',
#      'organizations_url': 'https://api.github.com/users/adrianrevilla009/orgs',
#      'repos_url': 'https://api.github.com/users/adrianrevilla009/repos',
#      'events_url': 'https://api.github.com/users/adrianrevilla009/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/adrianrevilla009/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'position': 108,
#     'line': 68,
#     'path': 'education_evaluation_notebook/models/education_notebook_exam.py',
#     'commit_id': '8c1dd132b2cf6b41202792cc095ee6d94bf8c029',
#     'created_at': '2019-11-28T07:52:42Z',
#     'updated_at': '2019-11-28T07:52:42Z',
#     'author_association': 'NONE',
#     'body': 'Esta función sirve para mostrar el número de líneas asociadas en el shortcut, por tanto necesito usarla. Lo que he hecho ha sido cambiar el modo de obtener ese número con el método que me has dicho.\r\nlen(exam.academic_record_ids)'}},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z',
#   'org': {'id': 4563868,
#    'login': 'avanzosc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/avanzosc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4563868?'}},
#  {'id': '10966721169',
#   'type': 'PushEvent',
#   'actor': {'id': 12443783,
#    'login': 'SamBeNuts',
#    'display_login': 'SamBeNuts',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SamBeNuts',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12443783?'},
#   'repo': {'id': 223216901,
#    'name': 'SamBeNuts/POO_ChatSystem_LAGER_SAULNIER',
#    'url': 'https://api.github.com/repos/SamBeNuts/POO_ChatSystem_LAGER_SAULNIER'},
#   'payload': {'push_id': 4330808227,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '14656973046836fd5e45435555939ad36bcd6f8e',
#    'before': '124988b0c92a7742ad101e0c612ec8b1e06be843',
#    'commits': [{'sha': '14656973046836fd5e45435555939ad36bcd6f8e',
#      'author': {'email': 'sambenuts.contact@gmail.com',
#       'name': 'Samuel Lager'},
#      'message': 'Fix problems with Eclipse',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SamBeNuts/POO_ChatSystem_LAGER_SAULNIER/commits/14656973046836fd5e45435555939ad36bcd6f8e'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721163',
#   'type': 'WatchEvent',
#   'actor': {'id': 5016110,
#    'login': 'lcyyork',
#    'display_login': 'lcyyork',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lcyyork',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5016110?'},
#   'repo': {'id': 12137658,
#    'name': 'ValeevGroup/mpqc',
#    'url': 'https://api.github.com/repos/ValeevGroup/mpqc'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z',
#   'org': {'id': 5217762,
#    'login': 'ValeevGroup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ValeevGroup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5217762?'}},
#  {'id': '10966721161',
#   'type': 'PushEvent',
#   'actor': {'id': 31996148,
#    'login': 'TechWorth',
#    'display_login': 'TechWorth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TechWorth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31996148?'},
#   'repo': {'id': 219856295,
#    'name': 'rxmii4269/COMP2140-DECODERS',
#    'url': 'https://api.github.com/repos/rxmii4269/COMP2140-DECODERS'},
#   'payload': {'push_id': 4330808218,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '160113847e3b798e1a52b63f8967a7ef0cc1f8ac',
#    'before': 'c5d2d6a9349a1c8bcff0b358b5e90b52c61c2f8f',
#    'commits': [{'sha': '160113847e3b798e1a52b63f8967a7ef0cc1f8ac',
#      'author': {'email': 'lornemiller21@gmail.com', 'name': 'TechWorth'},
#      'message': 'Admin GUI Working, Getting errors for the buttons',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rxmii4269/COMP2140-DECODERS/commits/160113847e3b798e1a52b63f8967a7ef0cc1f8ac'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721152',
#   'type': 'PushEvent',
#   'actor': {'id': 44140085,
#    'login': 'SebastianG77',
#    'display_login': 'SebastianG77',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SebastianG77',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44140085?'},
#   'repo': {'id': 152988005,
#    'name': 'SebastianG77/find-duplicated-property-keys',
#    'url': 'https://api.github.com/repos/SebastianG77/find-duplicated-property-keys'},
#   'payload': {'push_id': 4330808217,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Add_Case_Insensitive_Option',
#    'head': '6c25ba684bd12df218cb9b99f064d268882082db',
#    'before': '015609d6ce3ab3dc7ecfa7eb5d91c2a85fc312d9',
#    'commits': [{'sha': '6c25ba684bd12df218cb9b99f064d268882082db',
#      'author': {'email': 's.gostomski@hotmail.de', 'name': 'SebastianG'},
#      'message': 'feat(Property_Key): add additional functions parentPath and alternativeSpellingsPath to object PropertyKey to print the property path to the parent and the alternative spellings of the property key',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SebastianG77/find-duplicated-property-keys/commits/6c25ba684bd12df218cb9b99f064d268882082db'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721151',
#   'type': 'PushEvent',
#   'actor': {'id': 57338474,
#    'login': 'uncutjiademeng',
#    'display_login': 'uncutjiademeng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/uncutjiademeng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57338474?'},
#   'repo': {'id': 221628576,
#    'name': 'uncutjiademeng/hello-world',
#    'url': 'https://api.github.com/repos/uncutjiademeng/hello-world'},
#   'payload': {'push_id': 4330808216,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '93ad1c98c9194b6eef721052afb2d49f1a8bed71',
#    'before': 'e28b39a3e33d3446fdf0bb1da476bb66b9443b07',
#    'commits': [{'sha': '93ad1c98c9194b6eef721052afb2d49f1a8bed71',
#      'author': {'email': '57338474+uncutjiademeng@users.noreply.github.com',
#       'name': 'uncutjiademeng'},
#      'message': '第一次用\n\n第一次用',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/uncutjiademeng/hello-world/commits/93ad1c98c9194b6eef721052afb2d49f1a8bed71'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:42Z'},
#  {'id': '10966721156',
#   'type': 'ForkEvent',
#   'actor': {'id': 42667189,
#    'login': 'Eumenides1',
#    'display_login': 'Eumenides1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Eumenides1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42667189?'},
#   'repo': {'id': 173864682,
#    'name': 'katanala/lovers-website',
#    'url': 'https://api.github.com/repos/katanala/lovers-website'},
#   'payload': {'forkee': {'id': 224598662,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ1OTg2NjI=',
#     'name': 'lovers-website',
#     'full_name': 'Eumenides1/lovers-website',
#     'private': False,
#     'owner': {'login': 'Eumenides1',
#      'id': 42667189,
#      'node_id': 'MDQ6VXNlcjQyNjY3MTg5',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/42667189?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Eumenides1',
#      'html_url': 'https://github.com/Eumenides1',
#      'followers_url': 'https://api.github.com/users/Eumenides1/followers',
#      'following_url': 'https://api.github.com/users/Eumenides1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Eumenides1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Eumenides1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Eumenides1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Eumenides1/orgs',
#      'repos_url': 'https://api.github.com/users/Eumenides1/repos',
#      'events_url': 'https://api.github.com/users/Eumenides1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Eumenides1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/Eumenides1/lovers-website',
#     'description': "程序员的情侣网站 （programmer's website of lovers）",
#     'fork': True,
#     'url': 'https://api.github.com/repos/Eumenides1/lovers-website',
#     'forks_url': 'https://api.github.com/repos/Eumenides1/lovers-website/forks',
#     'keys_url': 'https://api.github.com/repos/Eumenides1/lovers-website/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Eumenides1/lovers-website/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Eumenides1/lovers-website/teams',
#     'hooks_url': 'https://api.github.com/repos/Eumenides1/lovers-website/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Eumenides1/lovers-website/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Eumenides1/lovers-website/events',
#     'assignees_url': 'https://api.github.com/repos/Eumenides1/lovers-website/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Eumenides1/lovers-website/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Eumenides1/lovers-website/tags',
#     'blobs_url': 'https://api.github.com/repos/Eumenides1/lovers-website/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Eumenides1/lovers-website/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Eumenides1/lovers-website/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Eumenides1/lovers-website/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Eumenides1/lovers-website/statuses/{sha}',
# ...
#       'labels_url': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/deployments',
#       'created_at': '2019-11-28T07:52:13Z',
#       'updated_at': '2019-11-28T07:52:26Z',
#       'pushed_at': '2019-11-28T07:52:37Z',
#       'git_url': 'git://github.com/devfactory-stg/mf-devfactory-stg-27765.git',
#       'ssh_url': 'git@github.com:devfactory-stg/mf-devfactory-stg-27765.git',
#       'clone_url': 'https://github.com/devfactory-stg/mf-devfactory-stg-27765.git',
#       'svn_url': 'https://github.com/devfactory-stg/mf-devfactory-stg-27765',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/pulls/1'},
#      'html': {'href': 'https://github.com/devfactory-stg/mf-devfactory-stg-27765/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/devfactory-stg/mf-devfactory-stg-27765/statuses/3b24ed8421ccc944153edaf3dd4d13ad71e80171'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z',
#   'org': {'id': 51926275,
#    'login': 'devfactory-stg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/devfactory-stg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51926275?'}},
#  {'id': '10966721115',
#   'type': 'CreateEvent',
#   'actor': {'id': 31172356,
#    'login': 'roy1441',
#    'display_login': 'roy1441',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/roy1441',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31172356?'},
#   'repo': {'id': 222850343,
#    'name': 'roy1441/Soccer-App',
#    'url': 'https://api.github.com/repos/roy1441/Soccer-App'},
#   'payload': {'ref': 'Second_submission',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Aplikasi untuk melihat jadwal pertandingan sepak bola pada liga - liga dunia, dan memiliki fitur fitur menarik lainnya',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z'},
#  {'id': '10966721120',
#   'type': 'PushEvent',
#   'actor': {'id': 12519405,
#    'login': 'guipaes',
#    'display_login': 'guipaes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/guipaes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12519405?'},
#   'repo': {'id': 216559312,
#    'name': 'tcruzfranca/proj2019Web2',
#    'url': 'https://api.github.com/repos/tcruzfranca/proj2019Web2'},
#   'payload': {'push_id': 4330808200,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/guilherme-isabelle',
#    'head': '7c269fe568debb38efc7d64fe9d96bfc89293634',
#    'before': '4368078e26ac3fc7d22efeab2f737d7476ac6739',
#    'commits': [{'sha': '7c269fe568debb38efc7d64fe9d96bfc89293634',
#      'author': {'email': 'gui@Guilherme-ACER.paes', 'name': 'Guilherme Paes'},
#      'message': 'Hackthon Web2 -PORQUE O MEU TIME BOTA PRA FERVER-O SOL RAIOU',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tcruzfranca/proj2019Web2/commits/7c269fe568debb38efc7d64fe9d96bfc89293634'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z'},
#  {'id': '10966721108',
#   'type': 'CreateEvent',
#   'actor': {'id': 17834918,
#    'login': 'jadomag',
#    'display_login': 'jadomag',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jadomag',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17834918?'},
#   'repo': {'id': 222881962,
#    'name': 'jadomag/summernote',
#    'url': 'https://api.github.com/repos/jadomag/summernote'},
#   'payload': {'ref': 'issue-2874',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': 'Super simple WYSIWYG editor',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z'},
#  {'id': '10966721095',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 893783,
#    'login': 'OZZlE',
#    'display_login': 'OZZlE',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OZZlE',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/893783?'},
#   'repo': {'id': 481872,
#    'name': 'hashicorp/vagrant',
#    'url': 'https://api.github.com/repos/hashicorp/vagrant'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/hashicorp/vagrant/issues/5232',
#     'repository_url': 'https://api.github.com/repos/hashicorp/vagrant',
#     'labels_url': 'https://api.github.com/repos/hashicorp/vagrant/issues/5232/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/hashicorp/vagrant/issues/5232/comments',
#     'events_url': 'https://api.github.com/repos/hashicorp/vagrant/issues/5232/events',
#     'html_url': 'https://github.com/hashicorp/vagrant/issues/5232',
#     'id': 55053158,
#     'node_id': 'MDU6SXNzdWU1NTA1MzE1OA==',
#     'number': 5232,
#     'title': 'NFS Mount fails when doing Vagrant Up',
#     'user': {'login': 'alyn000r',
#      'id': 8127706,
#      'node_id': 'MDQ6VXNlcjgxMjc3MDY=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/8127706?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alyn000r',
#      'html_url': 'https://github.com/alyn000r',
#      'followers_url': 'https://api.github.com/users/alyn000r/followers',
#      'following_url': 'https://api.github.com/users/alyn000r/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alyn000r/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alyn000r/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alyn000r/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alyn000r/orgs',
#      'repos_url': 'https://api.github.com/users/alyn000r/repos',
#      'events_url': 'https://api.github.com/users/alyn000r/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alyn000r/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 25816,
#       'node_id': 'MDU6TGFiZWwyNTgxNg==',
#       'url': 'https://api.github.com/repos/hashicorp/vagrant/labels/bug',
#       'name': 'bug',
#       'color': 'e11d21',
#       'default': True,
#       'description': None},
#      {'id': 218284866,
#       'node_id': 'MDU6TGFiZWwyMTgyODQ4NjY=',
#       'url': 'https://api.github.com/repos/hashicorp/vagrant/labels/synced-folders/nfs',
#       'name': 'synced-folders/nfs',
#       'color': 'fef2c0',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2015-01-21T17:53:22Z',
#     'updated_at': '2019-11-28T07:52:41Z',
#     'closed_at': '2015-07-09T16:23:04Z',
#     'author_association': 'NONE',
#     'body': 'I am trying to start up vagrant on my virtual box. It however freezes when mounting the nfs drive. Any help will be appreciated I have viewed and tried almost everything on the closed bug - 1941 but nothing helped.\n\nMy config: \nOS: MAC OS X 10.10\nVirtualBox: 4.3.12\nVagrant: 1.6.5\n\nthis is the debug log for help:\n\n```\n==> default: Mounting NFS shared folders...\n    DEBUG ssh: Checking whether SSH is ready...\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: SSH is ready!\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: Execute:  (sudo=false)\n    DEBUG ssh: Exit status: 0\n    DEBUG guest: Searching for cap: mount_nfs_folder\n    DEBUG guest: Checking in: redhat\n    DEBUG guest: Checking in: linux\n    DEBUG guest: Found cap: mount_nfs_folder in linux\n     INFO guest: Execute capability: mount_nfs_folder [#<Vagrant::Machine: default (VagrantPlugins::ProviderVirtualBox::Provider)>, "192.168.33.1", {"/host_profile_home"=>{:nfs=>true, :guestpath=>"/host_profile_home", :hostpath=>"/Users/nnasiruddin", :disabled=>false, :type=>:nfs, :map_uid=>502, :map_gid=>20, :nfs_udp=>true, :nfs_version=>3, :uuid=>"3137651595"}}] (redhat)\n    DEBUG ssh: Checking whether SSH is ready...\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: SSH is ready!\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: Execute:  (sudo=false)\n    DEBUG ssh: Exit status: 0\n    DEBUG guest: Searching for cap: shell_expand_guest_path\n    DEBUG guest: Checking in: redhat\n    DEBUG guest: Checking in: linux\n    DEBUG guest: Found cap: shell_expand_guest_path in linux\n     INFO guest: Execute capability: shell_expand_guest_path [#<Vagrant::Machine: default (VagrantPlugins::ProviderVirtualBox::Provider)>, "/host_profile_home"] (redhat)\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: Execute: echo; printf /host_profile_home (sudo=false)\n    DEBUG ssh: stdout: \n    /host_profile_home\n    DEBUG ssh: Exit status: 0\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: Execute: mkdir -p /host_profile_home (sudo=true)\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: Execute: echo; printf $SSH_AUTH_SOCK (sudo=false)\n    DEBUG ssh: stdout: \n    /tmp/ssh-TxhxzU2467/agent.2467\n    DEBUG ssh: Exit status: 0\n     INFO ssh: Setting SSH_AUTH_SOCK remotely: /tmp/ssh-TxhxzU2467/agent.2467\n    DEBUG ssh: Exit status: 0\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: Execute: mount -o \'vers=3,udp\' 192.168.33.1:\'/Users/nnasiruddin\' /host_profile_home (sudo=true)\n    DEBUG ssh: Re-using SSH connection.\n     INFO ssh: Execute: echo; printf $SSH_AUTH_SOCK (sudo=false)\n    DEBUG ssh: stdout: \n    /tmp/ssh-TxhxzU2467/agent.2467\n    DEBUG ssh: Exit status: 0\n     INFO ssh: Setting SSH_AUTH_SOCK remotely: /tmp/ssh-TxhxzU2467/agent.2467\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: Sending SSH keep-alive...\n    DEBUG ssh: stderr: mount.nfs: Connection timed out\n\n    DEBUG ssh: Exit status: 32\n     INFO retryable: Retryable exception raised: #<Vagrant::Errors::LinuxNFSMountF ...
#    'comment': {'url': 'https://api.github.com/repos/hashicorp/vagrant/issues/comments/559380983',
#     'html_url': 'https://github.com/hashicorp/vagrant/issues/5232#issuecomment-559380983',
#     'issue_url': 'https://api.github.com/repos/hashicorp/vagrant/issues/5232',
#     'id': 559380983,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU1OTM4MDk4Mw==',
#     'user': {'login': 'OZZlE',
#      'id': 893783,
#      'node_id': 'MDQ6VXNlcjg5Mzc4Mw==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/893783?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/OZZlE',
#      'html_url': 'https://github.com/OZZlE',
#      'followers_url': 'https://api.github.com/users/OZZlE/followers',
#      'following_url': 'https://api.github.com/users/OZZlE/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/OZZlE/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/OZZlE/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/OZZlE/subscriptions',
#      'organizations_url': 'https://api.github.com/users/OZZlE/orgs',
#      'repos_url': 'https://api.github.com/users/OZZlE/repos',
#      'events_url': 'https://api.github.com/users/OZZlE/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/OZZlE/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-11-28T07:52:41Z',
#     'updated_at': '2019-11-28T07:52:41Z',
#     'author_association': 'NONE',
#     'body': "I got this again now after my Mac crashed with vagrant running, MacOs Catalina (19A602). This time ctrl+c and vagrant ssh hasn't run everything like shell scripts etc "}},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z',
#   'org': {'id': 761456,
#    'login': 'hashicorp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hashicorp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/761456?'}},
#  {'id': '10966721086',
#   'type': 'PushEvent',
#   'actor': {'id': 15142701,
#    'login': 'nieqiurong',
#    'display_login': 'nieqiurong',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nieqiurong',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15142701?'},
#   'repo': {'id': 224371016,
#    'name': 'nieqiurong/go-web',
#    'url': 'https://api.github.com/repos/nieqiurong/go-web'},
#   'payload': {'push_id': 4330808181,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6a8d79a9778a7c6c29f1496b86c643b03156e55c',
#    'before': '80fab454b1b049f65909cc63585ab89a8f85840d',
#    'commits': [{'sha': '6a8d79a9778a7c6c29f1496b86c643b03156e55c',
#      'author': {'email': 'nieqiurong@163.com', 'name': '聂秋秋'},
#      'message': '命名规范',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nieqiurong/go-web/commits/6a8d79a9778a7c6c29f1496b86c643b03156e55c'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z'},
#  {'id': '10966721080',
#   'type': 'PushEvent',
#   'actor': {'id': 7677525,
#    'login': 'malk1405',
#    'display_login': 'malk1405',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/malk1405',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7677525?'},
#   'repo': {'id': 223015866,
#    'name': 'malk1405/hostza',
#    'url': 'https://api.github.com/repos/malk1405/hostza'},
#   'payload': {'push_id': 4330808177,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b2af3bcd61f3f19aea071a71ed092cb568bc519f',
#    'before': '7f71120775123cba5dbec950528ea36a6b695c42',
#    'commits': [{'sha': 'b2af3bcd61f3f19aea071a71ed092cb568bc519f',
#      'author': {'email': 'malk1405@mail.ru', 'name': 'malk'},
#      'message': 'Сделал глобальные стили',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/malk1405/hostza/commits/b2af3bcd61f3f19aea071a71ed092cb568bc519f'}]},
#   'public': True,
#   'created_at': '2019-11-28T07:52:41Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
r = requests.get("https://cat-fact.herokuapp.com/facts")
json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.post("https://cat-fact.herokuapp.com/facts")
json.loads(r.text)
# Out:
# {'message': 'Sign in first'}
